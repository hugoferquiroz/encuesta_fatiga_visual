# %% [markdown]
# # Análisis Estadístico Descriptivo - Síndrome Visual Informático
#
# Este notebook realiza un análisis estadístico descriptivo completo del conjunto de datos sobre el Síndrome Visual Informático (SVI), incluyendo análisis univariado y bivariado con visualizaciones.

# %% [markdown]
# ## 1. Configuración y Carga de Datos
#
# Importamos las bibliotecas necesarias y cargamos el conjunto de datos.

# %%
# Importar bibliotecas necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import os

# Configurar el directorio base
BASE_DIR = Path('d:/encuesta_fatiga_visual')

# Configurar paleta de colores (similar a Nature)
colors = ['#2166ac', '#4393c3', '#92c5de', '#d1e5f0', '#f7f7f7', '#fddbc7', '#f4a582', '#d6604d', '#b2182b']
sns.set_palette(sns.color_palette(colors))
sns.set_style("whitegrid")

# Establecer el estilo de las gráficas
plt.rcParams.update({
    'font.size': 10,
    'axes.labelsize': 12,
    'axes.titlesize': 14,
    'xtick.labelsize': 10,
    'ytick.labelsize': 10,
    'figure.titlesize': 16,
    'figure.dpi': 300,
    'savefig.dpi': 300,
    'savefig.bbox': 'tight'
})

# Cargar los datos
df = pd.read_csv(BASE_DIR / 'data/2_processed/df_models_synthetic.csv')

# Crear directorios si no existen
(BASE_DIR / 'stats').mkdir(exist_ok=True)
(BASE_DIR / 'output_graphs/univariado').mkdir(parents=True, exist_ok=True)
(BASE_DIR / 'output_graphs/bivariado').mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## 2. Descripción de Variables y Etiquetas
#
# Definimos los diccionarios de etiquetas para las variables categóricas y organizamos las variables por tipo.

# %%
# Definir diccionarios de etiquetas para variables categóricas
label_dict = {
    'sexo': {1: 'Masculino', 0: 'Femenino'},
    'estado_civil': {0: 'Soltero', 1: 'Casado', 2: 'Divorciado', 3: 'Viudo'},
    'ingresos_mensuales': {0: 'Menos de $3,000', 1: '$3,001 - $5,000', 
                          2: '$5,001 - $7,000', 3: 'Más de $7,000'},
    'condiciones_oculares': {1: 'Sí', 0: 'No'},
    'lentes': {1: 'Sí', 0: 'No'},
    'iluminacion': {1: 'Adecuada', 0: 'Inadecuada'},
    'frecuencia_de_pausas': {1: 'Frecuente', 2: 'Ocasional', 0: 'Nulo'},
    'uso_de_dispositivos': {0: 'menos de 1 hora', 1: '1 - 2 h', 
                          2: '2 - 4 h', 3: 'Mayor de 4h'},
    'distancia_hacia_el_monitor': {0: 'Menor de 30 cm', 1: '30 - 60 cm', 
                                 2: 'Mayor de 60 cm'},
    'svi': {1: 'Sí', 0: 'No'}
}

# Clasificar variables por tipo
numerical_vars = ['edad', 'experiencia_radiologia', 'tiempo_de_exposicion',
                 'duracion_de_jornada', 'puntaje_sindrome_visual_informatico']

categorical_vars = ['sexo', 'estado_civil', 'ingresos_mensuales', 'condiciones_oculares',
                   'lentes', 'iluminacion', 'frecuencia_de_pausas', 'uso_de_dispositivos',
                   'distancia_hacia_el_monitor', 'severidad_svi', 'svi']

# Mostrar información básica del dataset
print("Información del Dataset:")
print("-" * 50)
print(df.info())
print("\nEstadísticas básicas:")
print("-" * 50)
print(df.describe())
# Out:
# Información del Dataset:
# --------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 64 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   edad                                 40 non-null     int64
#  1   experiencia_radiologia               40 non-null     float64
#  2   tiempo_de_exposicion                 40 non-null     float64
#  3   duracion_de_jornada                  40 non-null     float64
#  4   sexo                                 40 non-null     int64
#  5   estado_civil                         40 non-null     int64
#  6   ingresos_mensuales                   40 non-null     int64
#  7   condiciones_oculares                 40 non-null     int64
#  8   lentes                               40 non-null     int64
#  9   iluminacion                          40 non-null     int64
#  10  frecuencia_de_pausas                 40 non-null     int64
#  11  uso_de_dispositivos                  40 non-null     int64
#  12  distancia_hacia_el_monitor           40 non-null     int64
#  13  ardor_frecuencia                     40 non-null     int64
#  14  ardor_intensidad                     40 non-null     int64
#  15  ardor_severidad                      40 non-null     int64
#  16  picor_frecuencia                     40 non-null     int64
#  17  picor_intensidad                     40 non-null     int64
#  18  picor_severidad                      40 non-null     int64
#  19  sensacion_cuerpo_extraño_frecuencia  40 non-null     int64
#  20  sensacion_cuerpo_extraño_intensidad  40 non-null     int64
#  21  sensacion_cuerpo_extraño_severidad   40 non-null     int64
#  22  lagrimeo_frecuencia                  40 non-null     int64
#  23  lagrimeo_intensidad                  40 non-null     int64
#  24  lagrimeo_severidad                   40 non-null     int64
#  25  parpadeo_excesivo_frecuencia         40 non-null     int64
#  26  parpadeo_excesivo_intensidad         40 non-null     int64
#  27  parpadeo_excesivo_severidad          40 non-null     int64
#  28  enrojecimiento_ocular_frecuencia     40 non-null     int64
#  29  enrojecimiento_ocular_intensidad     40 non-null     int64
#  30  enrojecimiento_ocular_severidad      40 non-null     int64
#  31  dolor_ocular_frecuencia              40 non-null     int64
#  32  dolor_ocular_intensidad              40 non-null     int64
#  33  dolor_ocular_severidad               40 non-null     int64
#  34  pesadez_parpados_frecuencia          40 non-null     int64
#  35  pesadez_parpados_intensidad          40 non-null     int64
#  36  pesadez_parpados_severidad           40 non-null     int64
#  37  sequedad_frecuencia                  40 non-null     int64
#  38  sequedad_intensidad                  40 non-null     int64
#  39  sequedad_severidad                   40 non-null     int64
#  40  vision_borrosa_frecuencia            40 non-null     int64
#  41  vision_borrosa_intensidad            40 non-null     int64
#  42  vision_borrosa_severidad             40 non-null     int64
#  43  vision_doble_frecuencia              40 non-null     int64
#  44  vision_doble_intensidad              40 non-null     int64
#  45  vision_doble_severidad               40 non-null     int64
#  46  dificultad_al_enfocar_frecuencia     40 non-null     int64
#  47  dificultad_al_enfocar_intensidad     40 non-null     int64
#  48  dificultad_al_enfocar_severidad      40 non-null     int64
#  49  aumento_sensiblidad_luz_frecuencia   40 non-null     int64
#  50  aumento_sensiblidad_luz_intensidad   40 non-null     int64
#  51  aumento_sensiblidad_luz_severidad    40 non-null     int64
#  52  halos_de_colores_frecuencia          40 non-null     int64
#  53  halos_de_colores_intensidad          40 non-null     int64
#  54  halos_de_colores_severidad           40 non-null     int64
#  55  sensacion_de_ver_peor_frecuencia     40 non-null     int64
#  56  sensacion_de_ver_peor_intensidad     40 non-null     int64
#  57  sensacion_de_ver_peor_severidad      40 non-null     int64
#  58  dolor_de_cabeza_frecuencia           40 non-null     int64
#  59  dolor_de_cabeza_intensidad           40 non-null     int64
#  60  dolor_de_cabeza_severidad            40 non-null     int64
#  61  puntaje_sindrome_visual_informatico  40 non-null     int64
#  62  svi                                  40 non-null     int64
#  63  severidad_svi                        40 non-null     object
# dtypes: float64(3), int64(60), object(1)
# memory usage: 20.1+ KB
# None
#
# Estadísticas básicas:
# --------------------------------------------------
#             edad  experiencia_radiologia  tiempo_de_exposicion  \
# count  40.000000               40.000000             40.000000
# mean   32.850000                4.522500             11.925000
# std     5.404414                2.498768              2.463971
# min    25.000000                1.000000              8.000000
# 25%    28.750000                2.650000             10.000000
# 50%    33.000000                4.400000             12.000000
# 75%    36.000000                6.750000             13.000000
# max    45.000000                9.300000             16.000000
#
#        duracion_de_jornada       sexo  estado_civil  ingresos_mensuales  \
# count            40.000000  40.000000     40.000000           40.000000
# mean             11.500000   0.550000      0.975000            1.550000
# std               3.351234   0.503831      0.891196            0.814925
# min               6.000000   0.000000      0.000000            0.000000
# 25%               8.000000   0.000000      0.000000            1.000000
# 50%              13.000000   1.000000      1.000000            2.000000
# 75%              14.000000   1.000000      1.000000            2.000000
# max              16.000000   1.000000      3.000000            3.000000
#
#        condiciones_oculares    lentes  iluminacion  ...  \
# count             40.000000  40.00000    40.000000  ...
# mean               0.575000   0.62500     0.750000  ...
# std                0.500641   0.49029     0.438529  ...
# min                0.000000   0.00000     0.000000  ...
# 25%                0.000000   0.00000     0.750000  ...
# 50%                1.000000   1.00000     1.000000  ...
# 75%                1.000000   1.00000     1.000000  ...
# max                1.000000   1.00000     1.000000  ...
#
#        halos_de_colores_intensidad  halos_de_colores_severidad  \
# count                    40.000000                   40.000000
# mean                      0.550000                    0.850000
# std                       0.677476                    1.251666
# min                       0.000000                    0.000000
# 25%                       0.000000                    0.000000
# 50%                       0.000000                    0.000000
# 75%                       1.000000                    1.000000
# max                       2.000000                    4.000000
#
#        sensacion_de_ver_peor_frecuencia  sensacion_de_ver_peor_intensidad  \
# count                         40.000000                         40.000000
# mean                           0.825000                          0.775000
# std                            0.902631                          0.861945
# min                            0.000000                          0.000000
# 25%                            0.000000                          0.000000
# 50%                            0.500000                          0.500000
# 75%                            2.000000                          2.000000
# max                            2.000000                          2.000000
#
#        sensacion_de_ver_peor_severidad  dolor_de_cabeza_frecuencia  \
# count                        40.000000                   40.000000
# mean                          1.300000                    0.450000
# std                           1.572194                    0.597001
# min                           0.000000                    0.000000
# 25%                           0.000000                    0.000000
# 50%                           0.500000                    0.000000
# 75%                           2.000000                    1.000000
# max                           4.000000                    2.000000
#
#        dolor_de_cabeza_intensidad  dolor_de_cabeza_severidad  \
# count                   40.000000                  40.000000
# mean                     0.575000                   0.625000
# std                      0.780779                   0.837808
# min                      0.000000                   0.000000
# 25%                      0.000000                   0.000000
# 50%                      0.000000                   0.000000
# 75%                      1.000000                   1.000000
# max                      2.000000                   2.000000
#
#        puntaje_sindrome_visual_informatico        svi
# count                            40.000000  40.000000
# mean                             14.375000   0.875000
# std                               8.705105   0.334932
# min                               1.000000   0.000000
# 25%                               6.000000   1.000000
# 50%                              13.500000   1.000000
# 75%                              20.250000   1.000000
# max                              34.000000   1.000000
#
# [8 rows x 63 columns]

# %% [markdown]
# ## 3. Análisis Univariado - Variables Numéricas
#
# Calculamos estadísticas descriptivas y generamos visualizaciones para variables numéricas.

# %%
# Calcular estadísticas descriptivas para variables numéricas
numeric_stats = df[numerical_vars].describe()
numeric_stats.to_csv(BASE_DIR / 'stats/descriptive_stats.csv')

# Crear histogramas para variables numéricas
for var in numerical_vars:
    plt.figure(figsize=(10, 6))
    sns.histplot(data=df, x=var, kde=True)
    plt.title(f'Distribución de {var}')
    plt.xlabel(var.replace('_', ' ').title())
    plt.ylabel('Frecuencia')
    plt.savefig(BASE_DIR / f'output_graphs/univariado/hist_{var}.png')
    plt.close()

# Mostrar estadísticas descriptivas
print("Estadísticas Descriptivas para Variables Numéricas:")
print("-" * 70)
print(numeric_stats)
# Out:
# Estadísticas Descriptivas para Variables Numéricas:
# ----------------------------------------------------------------------
#             edad  experiencia_radiologia  tiempo_de_exposicion  \
# count  40.000000               40.000000             40.000000
# mean   32.850000                4.522500             11.925000
# std     5.404414                2.498768              2.463971
# min    25.000000                1.000000              8.000000
# 25%    28.750000                2.650000             10.000000
# 50%    33.000000                4.400000             12.000000
# 75%    36.000000                6.750000             13.000000
# max    45.000000                9.300000             16.000000
#
#        duracion_de_jornada  puntaje_sindrome_visual_informatico
# count            40.000000                            40.000000
# mean             11.500000                            14.375000
# std               3.351234                             8.705105
# min               6.000000                             1.000000
# 25%               8.000000                             6.000000
# 50%              13.000000                            13.500000
# 75%              14.000000                            20.250000
# max              16.000000                            34.000000

# %% [markdown]
# ## 4. Análisis Univariado - Variables Categóricas
#
# Calculamos frecuencias y proporciones, y generamos visualizaciones para variables categóricas.

# %%
# Calcular frecuencias y proporciones para variables categóricas
categorical_stats = pd.DataFrame()

for var in categorical_vars:
    # Calcular frecuencias y proporciones
    freq_table = pd.DataFrame({
        'Frecuencia': df[var].value_counts(),
        'Porcentaje': df[var].value_counts(normalize=True) * 100
    })
    
    # Agregar etiquetas si están disponibles
    if var in label_dict:
        freq_table.index = freq_table.index.map(label_dict[var])
    
    # Guardar en el DataFrame general
    categorical_stats = pd.concat([categorical_stats, 
                                 freq_table.add_suffix(f'_{var}')], axis=1)

# Guardar estadísticas categóricas
categorical_stats.to_csv(BASE_DIR / 'stats/categorical_stats.csv')

# Crear gráficos de barras para variables categóricas
for var in categorical_vars:
    plt.figure(figsize=(10, 6))
    
    # Preparar datos para el gráfico
    if var in label_dict:
        # Crear una serie con las etiquetas mapeadas
        data = df[var].map(label_dict[var]).value_counts()
    else:
        data = df[var].value_counts()
    
    # Crear gráfico de barras usando directamente los datos procesados
    ax = data.plot(kind='bar')
    plt.title(f'Distribución de {var.replace("_", " ").title()}')
    plt.xlabel(var.replace('_', ' ').title())
    plt.ylabel('Frecuencia')
    
    # Agregar valores en las barras
    for i, v in enumerate(data):
        ax.text(i, v, str(v), ha='center', va='bottom')
    
    # Rotar etiquetas si son largas
    plt.xticks(rotation=45, ha='right')
    
    # Ajustar layout y guardar
    plt.tight_layout()
    plt.savefig(BASE_DIR / f'output_graphs/univariado/bar_{var}.png')
    plt.close()

# Mostrar estadísticas categóricas
print("Estadísticas para Variables Categóricas:")
print("-" * 70)
print(categorical_stats)
# Out:
# Estadísticas para Variables Categóricas:
# ----------------------------------------------------------------------
#                  Frecuencia_sexo  Porcentaje_sexo  Frecuencia_estado_civil  \
# Masculino                   22.0             55.0                      NaN
# Femenino                    18.0             45.0                      NaN
# Casado                       NaN              NaN                     18.0
# Soltero                      NaN              NaN                     13.0
# Divorciado                   NaN              NaN                      6.0
# Viudo                        NaN              NaN                      3.0
# $5,001 - $7,000              NaN              NaN                      NaN
# $3,001 - $5,000              NaN              NaN                      NaN
# Menos de $3,000              NaN              NaN                      NaN
# Más de $7,000                NaN              NaN                      NaN
# Sí                           NaN              NaN                      NaN
# No                           NaN              NaN                      NaN
# Adecuada                     NaN              NaN                      NaN
# Inadecuada                   NaN              NaN                      NaN
# Frecuente                    NaN              NaN                      NaN
# Ocasional                    NaN              NaN                      NaN
# Nulo                         NaN              NaN                      NaN
# Mayor de 4h                  NaN              NaN                      NaN
# 1 - 2 h                      NaN              NaN                      NaN
# menos de 1 hora              NaN              NaN                      NaN
# 2 - 4 h                      NaN              NaN                      NaN
# 30 - 60 cm                   NaN              NaN                      NaN
# Mayor de 60 cm               NaN              NaN                      NaN
# Menor de 30 cm               NaN              NaN                      NaN
# Moderado                     NaN              NaN                      NaN
# Leve                         NaN              NaN                      NaN
# Severo                       NaN              NaN                      NaN
# No SVI                       NaN              NaN                      NaN
#
#                  Porcentaje_estado_civil  Frecuencia_ingresos_mensuales  \
# Masculino                            NaN                            NaN
# Femenino                             NaN                            NaN
# Casado                              45.0                            NaN
# Soltero                             32.5                            NaN
# Divorciado                          15.0                            NaN
# Viudo                                7.5                            NaN
# $5,001 - $7,000                      NaN                           21.0
# $3,001 - $5,000                      NaN                           11.0
# Menos de $3,000                      NaN                            5.0
# Más de $7,000                        NaN                            3.0
# Sí                                   NaN                            NaN
# No                                   NaN                            NaN
# Adecuada                             NaN                            NaN
# Inadecuada                           NaN                            NaN
# Frecuente                            NaN                            NaN
# Ocasional                            NaN                            NaN
# Nulo                                 NaN                            NaN
# Mayor de 4h                          NaN                            NaN
# 1 - 2 h                              NaN                            NaN
# menos de 1 hora                      NaN                            NaN
# 2 - 4 h                              NaN                            NaN
# 30 - 60 cm                           NaN                            NaN
# Mayor de 60 cm                       NaN                            NaN
# Menor de 30 cm                       NaN                            NaN
# Moderado                             NaN                            NaN
# Leve                                 NaN                            NaN
# Severo                               NaN                            NaN
# No SVI                               NaN                            NaN
#
#                  Porcentaje_ingresos_mensuales  \
# Masculino                                  NaN
# Femenino                                   NaN
# Casado                                     NaN
# Soltero                                    NaN
# Divorciado                                 NaN
# Viudo                                      NaN
# $5,001 - $7,000                           52.5
# $3,001 - $5,000                           27.5
# Menos de $3,000                           12.5
# Más de $7,000                              7.5
# Sí                                         NaN
# No                                         NaN
# Adecuada                                   NaN
# Inadecuada                                 NaN
# Frecuente                                  NaN
# Ocasional                                  NaN
# Nulo                                       NaN
# Mayor de 4h                                NaN
# 1 - 2 h                                    NaN
# menos de 1 hora                            NaN
# 2 - 4 h                                    NaN
# 30 - 60 cm                                 NaN
# Mayor de 60 cm                             NaN
# Menor de 30 cm                             NaN
# Moderado                                   NaN
# Leve                                       NaN
# Severo                                     NaN
# No SVI                                     NaN
#
#                  Frecuencia_condiciones_oculares  \
# Masculino                                    NaN
# Femenino                                     NaN
# Casado                                       NaN
# Soltero                                      NaN
# Divorciado                                   NaN
# Viudo                                        NaN
# $5,001 - $7,000                              NaN
# $3,001 - $5,000                              NaN
# Menos de $3,000                              NaN
# Más de $7,000                                NaN
# Sí                                          23.0
# No                                          17.0
# Adecuada                                     NaN
# Inadecuada                                   NaN
# Frecuente                                    NaN
# Ocasional                                    NaN
# Nulo                                         NaN
# Mayor de 4h                                  NaN
# 1 - 2 h                                      NaN
# menos de 1 hora                              NaN
# 2 - 4 h                                      NaN
# 30 - 60 cm                                   NaN
# Mayor de 60 cm                               NaN
# Menor de 30 cm                               NaN
# Moderado                                     NaN
# Leve                                         NaN
# Severo                                       NaN
# No SVI                                       NaN
#
#                  Porcentaje_condiciones_oculares  Frecuencia_lentes  \
# Masculino                                    NaN                NaN
# Femenino                                     NaN                NaN
# Casado                                       NaN                NaN
# Soltero                                      NaN                NaN
# Divorciado                                   NaN                NaN
# Viudo                                        NaN                NaN
# $5,001 - $7,000                              NaN                NaN
# $3,001 - $5,000                              NaN                NaN
# Menos de $3,000                              NaN                NaN
# Más de $7,000                                NaN                NaN
# Sí                                          57.5               25.0
# No                                          42.5               15.0
# Adecuada                                     NaN                NaN
# Inadecuada                                   NaN                NaN
# Frecuente                                    NaN                NaN
# Ocasional                                    NaN                NaN
# Nulo                                         NaN                NaN
# Mayor de 4h                                  NaN                NaN
# 1 - 2 h                                      NaN                NaN
# menos de 1 hora                              NaN                NaN
# 2 - 4 h                                      NaN                NaN
# 30 - 60 cm                                   NaN                NaN
# Mayor de 60 cm                               NaN                NaN
# Menor de 30 cm                               NaN                NaN
# Moderado                                     NaN                NaN
# Leve                                         NaN                NaN
# Severo                                       NaN                NaN
# No SVI                                       NaN                NaN
#
#                  Porcentaje_lentes  ...  Frecuencia_frecuencia_de_pausas  \
# Masculino                      NaN  ...                              NaN
# Femenino                       NaN  ...                              NaN
# Casado                         NaN  ...                              NaN
# Soltero                        NaN  ...                              NaN
# Divorciado                     NaN  ...                              NaN
# Viudo                          NaN  ...                              NaN
# $5,001 - $7,000                NaN  ...                              NaN
# $3,001 - $5,000                NaN  ...                              NaN
# Menos de $3,000                NaN  ...                              NaN
# Más de $7,000                  NaN  ...                              NaN
# Sí                            62.5  ...                              NaN
# No                            37.5  ...                              NaN
# Adecuada                       NaN  ...                              NaN
# Inadecuada                     NaN  ...                              NaN
# Frecuente                      NaN  ...                             19.0
# Ocasional                      NaN  ...                             11.0
# Nulo                           NaN  ...                             10.0
# Mayor de 4h                    NaN  ...                              NaN
# 1 - 2 h                        NaN  ...                              NaN
# menos de 1 hora                NaN  ...                              NaN
# 2 - 4 h                        NaN  ...                              NaN
# 30 - 60 cm                     NaN  ...                              NaN
# Mayor de 60 cm                 NaN  ...                              NaN
# Menor de 30 cm                 NaN  ...                              NaN
# Moderado                       NaN  ...                              NaN
# Leve                           NaN  ...                              NaN
# Severo                         NaN  ...                              NaN
# No SVI                         NaN  ...                              NaN
#
#                  Porcentaje_frecuencia_de_pausas  \
# Masculino                                    NaN
# Femenino                                     NaN
# Casado                                       NaN
# Soltero                                      NaN
# Divorciado                                   NaN
# Viudo                                        NaN
# $5,001 - $7,000                              NaN
# $3,001 - $5,000                              NaN
# Menos de $3,000                              NaN
# Más de $7,000                                NaN
# Sí                                           NaN
# No                                           NaN
# Adecuada                                     NaN
# Inadecuada                                   NaN
# Frecuente                                   47.5
# Ocasional                                   27.5
# Nulo                                        25.0
# Mayor de 4h                                  NaN
# 1 - 2 h                                      NaN
# menos de 1 hora                              NaN
# 2 - 4 h                                      NaN
# 30 - 60 cm                                   NaN
# Mayor de 60 cm                               NaN
# Menor de 30 cm                               NaN
# Moderado                                     NaN
# Leve                                         NaN
# Severo                                       NaN
# No SVI                                       NaN
#
#                  Frecuencia_uso_de_dispositivos  \
# Masculino                                   NaN
# Femenino                                    NaN
# Casado                                      NaN
# Soltero                                     NaN
# Divorciado                                  NaN
# Viudo                                       NaN
# $5,001 - $7,000                             NaN
# $3,001 - $5,000                             NaN
# Menos de $3,000                             NaN
# Más de $7,000                               NaN
# Sí                                          NaN
# No                                          NaN
# Adecuada                                    NaN
# Inadecuada                                  NaN
# Frecuente                                   NaN
# Ocasional                                   NaN
# Nulo                                        NaN
# Mayor de 4h                                33.0
# 1 - 2 h                                     4.0
# menos de 1 hora                             2.0
# 2 - 4 h                                     1.0
# 30 - 60 cm                                  NaN
# Mayor de 60 cm                              NaN
# Menor de 30 cm                              NaN
# Moderado                                    NaN
# Leve                                        NaN
# Severo                                      NaN
# No SVI                                      NaN
#
#                  Porcentaje_uso_de_dispositivos  \
# Masculino                                   NaN
# Femenino                                    NaN
# Casado                                      NaN
# Soltero                                     NaN
# Divorciado                                  NaN
# Viudo                                       NaN
# $5,001 - $7,000                             NaN
# $3,001 - $5,000                             NaN
# Menos de $3,000                             NaN
# Más de $7,000                               NaN
# Sí                                          NaN
# No                                          NaN
# Adecuada                                    NaN
# Inadecuada                                  NaN
# Frecuente                                   NaN
# Ocasional                                   NaN
# Nulo                                        NaN
# Mayor de 4h                                82.5
# 1 - 2 h                                    10.0
# menos de 1 hora                             5.0
# 2 - 4 h                                     2.5
# 30 - 60 cm                                  NaN
# Mayor de 60 cm                              NaN
# Menor de 30 cm                              NaN
# Moderado                                    NaN
# Leve                                        NaN
# Severo                                      NaN
# No SVI                                      NaN
#
#                  Frecuencia_distancia_hacia_el_monitor  \
# Masculino                                          NaN
# Femenino                                           NaN
# Casado                                             NaN
# Soltero                                            NaN
# Divorciado                                         NaN
# Viudo                                              NaN
# $5,001 - $7,000                                    NaN
# $3,001 - $5,000                                    NaN
# Menos de $3,000                                    NaN
# Más de $7,000                                      NaN
# Sí                                                 NaN
# No                                                 NaN
# Adecuada                                           NaN
# Inadecuada                                         NaN
# Frecuente                                          NaN
# Ocasional                                          NaN
# Nulo                                               NaN
# Mayor de 4h                                        NaN
# 1 - 2 h                                            NaN
# menos de 1 hora                                    NaN
# 2 - 4 h                                            NaN
# 30 - 60 cm                                        28.0
# Mayor de 60 cm                                     6.0
# Menor de 30 cm                                     6.0
# Moderado                                           NaN
# Leve                                               NaN
# Severo                                             NaN
# No SVI                                             NaN
#
#                  Porcentaje_distancia_hacia_el_monitor  \
# Masculino                                          NaN
# Femenino                                           NaN
# Casado                                             NaN
# Soltero                                            NaN
# Divorciado                                         NaN
# Viudo                                              NaN
# $5,001 - $7,000                                    NaN
# $3,001 - $5,000                                    NaN
# Menos de $3,000                                    NaN
# Más de $7,000                                      NaN
# Sí                                                 NaN
# No                                                 NaN
# Adecuada                                           NaN
# Inadecuada                                         NaN
# Frecuente                                          NaN
# Ocasional                                          NaN
# Nulo                                               NaN
# Mayor de 4h                                        NaN
# 1 - 2 h                                            NaN
# menos de 1 hora                                    NaN
# 2 - 4 h                                            NaN
# 30 - 60 cm                                        70.0
# Mayor de 60 cm                                    15.0
# Menor de 30 cm                                    15.0
# Moderado                                           NaN
# Leve                                               NaN
# Severo                                             NaN
# No SVI                                             NaN
#
#                  Frecuencia_severidad_svi  Porcentaje_severidad_svi  \
# Masculino                             NaN                       NaN
# Femenino                              NaN                       NaN
# Casado                                NaN                       NaN
# Soltero                               NaN                       NaN
# Divorciado                            NaN                       NaN
# Viudo                                 NaN                       NaN
# $5,001 - $7,000                       NaN                       NaN
# $3,001 - $5,000                       NaN                       NaN
# Menos de $3,000                       NaN                       NaN
# Más de $7,000                         NaN                       NaN
# Sí                                    NaN                       NaN
# No                                    NaN                       NaN
# Adecuada                              NaN                       NaN
# Inadecuada                            NaN                       NaN
# Frecuente                             NaN                       NaN
# Ocasional                             NaN                       NaN
# Nulo                                  NaN                       NaN
# Mayor de 4h                           NaN                       NaN
# 1 - 2 h                               NaN                       NaN
# menos de 1 hora                       NaN                       NaN
# 2 - 4 h                               NaN                       NaN
# 30 - 60 cm                            NaN                       NaN
# Mayor de 60 cm                        NaN                       NaN
# Menor de 30 cm                        NaN                       NaN
# Moderado                             14.0                      35.0
# Leve                                 11.0                      27.5
# Severo                               10.0                      25.0
# No SVI                                5.0                      12.5
#
#                  Frecuencia_svi  Porcentaje_svi
# Masculino                   NaN             NaN
# Femenino                    NaN             NaN
# Casado                      NaN             NaN
# Soltero                     NaN             NaN
# Divorciado                  NaN             NaN
# Viudo                       NaN             NaN
# $5,001 - $7,000             NaN             NaN
# $3,001 - $5,000             NaN             NaN
# Menos de $3,000             NaN             NaN
# Más de $7,000               NaN             NaN
# Sí                         35.0            87.5
# No                          5.0            12.5
# Adecuada                    NaN             NaN
# Inadecuada                  NaN             NaN
# Frecuente                   NaN             NaN
# Ocasional                   NaN             NaN
# Nulo                        NaN             NaN
# Mayor de 4h                 NaN             NaN
# 1 - 2 h                     NaN             NaN
# menos de 1 hora             NaN             NaN
# 2 - 4 h                     NaN             NaN
# 30 - 60 cm                  NaN             NaN
# Mayor de 60 cm              NaN             NaN
# Menor de 30 cm              NaN             NaN
# Moderado                    NaN             NaN
# Leve                        NaN             NaN
# Severo                      NaN             NaN
# No SVI                      NaN             NaN
#
# [28 rows x 22 columns]

# %% [markdown]
# ## 5. Análisis Bivariado con SVI
#
# Analizamos las relaciones entre las variables y el SVI (Síndrome Visual Informático).

# %%
# 1. Análisis de correlación y asociación

# 1.1 Correlaciones entre variables numéricas
correlation_matrix = df[numerical_vars].corr()
correlation_matrix.to_csv(BASE_DIR / 'stats/correlation_matrix.csv')

# Crear mapa de calor de correlaciones numéricas
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='RdBu_r', center=0, fmt='.2f')
plt.title('Matriz de Correlación - Variables Numéricas')
plt.tight_layout()
plt.savefig(BASE_DIR / 'output_graphs/bivariado/correlation_heatmap_numeric.png')
plt.close()

# 1.2 Análisis de asociación para variables categóricas (V de Cramer)
categorical_vars_no_svi = [x for x in categorical_vars if x != 'svi']
n_cats = len(categorical_vars_no_svi)
cramer_matrix = pd.DataFrame(np.zeros((n_cats, n_cats)), 
                           index=categorical_vars_no_svi,
                           columns=categorical_vars_no_svi)

def cramers_v(var1, var2):
    confusion_matrix = pd.crosstab(var1, var2)
    chi2 = chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    min_dim = min(confusion_matrix.shape) - 1
    return np.sqrt(chi2 / (n * min_dim))

# Importar chi2_contingency
from scipy.stats import chi2_contingency

# Calcular V de Cramer para cada par de variables categóricas
for i, var1 in enumerate(categorical_vars_no_svi):
    for j, var2 in enumerate(categorical_vars_no_svi):
        if i > j:  # Solo calculamos la mitad inferior
            cramer_v = cramers_v(df[var1], df[var2])
            cramer_matrix.iloc[i, j] = cramer_v
            cramer_matrix.iloc[j, i] = cramer_v
        elif i == j:
            cramer_matrix.iloc[i, j] = 1.0

# Guardar matriz de asociación
cramer_matrix.to_csv(BASE_DIR / 'stats/cramer_v_matrix.csv')

# Crear mapa de calor para asociaciones categóricas
plt.figure(figsize=(12, 8))
sns.heatmap(cramer_matrix, annot=True, cmap='RdBu_r', center=0.5, fmt='.2f')
plt.title('Matriz de Asociación (V de Cramer) - Variables Categóricas')
plt.tight_layout()
plt.savefig(BASE_DIR / 'output_graphs/bivariado/correlation_heatmap_categorical.png')
plt.close()

# 2. Análisis por tipo de variable con respecto a SVI

# 2.1 Variables numéricas vs SVI
for var in numerical_vars:
    # Crear figura con dos subplots
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
    
    # Gráfico de violín
    sns.violinplot(data=df, x='svi', y=var, ax=ax1)
    ax1.set_title(f'Violin Plot: {var.replace("_", " ").title()} por SVI')
    ax1.set_xlabel('SVI')
    if 'svi' in label_dict:
        ax1.set_xticklabels(['No', 'Sí'])
    ax1.set_ylabel(var.replace('_', ' ').title())
    
    # Gráfico de caja
    sns.boxplot(data=df, x='svi', y=var, ax=ax2)
    ax2.set_title(f'Box Plot: {var.replace("_", " ").title()} por SVI')
    ax2.set_xlabel('SVI')
    if 'svi' in label_dict:
        ax2.set_xticklabels(['No', 'Sí'])
    ax2.set_ylabel(var.replace('_', ' ').title())
    
    plt.tight_layout()
    plt.savefig(BASE_DIR / f'output_graphs/bivariado/dist_{var}_vs_svi.png')
    plt.close()

# 2.2 Variables categóricas vs SVI - Gráficos de barras apiladas
for var in categorical_vars_no_svi:
    plt.figure(figsize=(10, 6))
    
    # Calcular proporciones y aplicar etiquetas
    if var in label_dict:
        df_temp = df.copy()
        df_temp[var] = df_temp[var].map(label_dict[var])
        prop_data = pd.crosstab(df_temp[var], df_temp['svi'].map(label_dict['svi']), 
                               normalize='index') * 100
    else:
        prop_data = pd.crosstab(df[var], df['svi'].map(label_dict['svi']), 
                               normalize='index') * 100
    
    # Crear gráfico de barras apiladas
    ax = prop_data.plot(kind='bar', stacked=True)
    plt.title(f'Distribución de SVI por {var.replace("_", " ").title()}')
    plt.xlabel(var.replace("_", " ").title())
    plt.ylabel('Porcentaje')
    
    # Agregar porcentajes en las barras
    for c in ax.containers:
        ax.bar_label(c, fmt='%.1f%%', label_type='center')
    
    # Rotar etiquetas si son largas
    plt.xticks(rotation=45, ha='right')
    
    # Ajustar layout y guardar
    plt.tight_layout()
    plt.savefig(BASE_DIR / f'output_graphs/bivariado/bar_{var}_vs_svi.png')
    plt.close()

print("Análisis bivariado completado. Se han generado:")
print("1. Matrices de correlación/asociación:")
print("   - Correlación de Pearson para variables numéricas")
print("   - V de Cramer para variables categóricas")
print("2. Visualizaciones:")
print("   - Violin plots y Box plots para variables numéricas vs SVI")
print("   - Gráficos de barras apiladas para variables categóricas vs SVI")
print("Todos los gráficos han sido guardados en los directorios correspondientes.")
# Out:
# C:\Users\hugo_\AppData\Local\Temp\ipykernel_19952\2694410693.py:65: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(['No', 'Sí'])
# C:\Users\hugo_\AppData\Local\Temp\ipykernel_19952\2694410693.py:73: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['No', 'Sí'])
# C:\Users\hugo_\AppData\Local\Temp\ipykernel_19952\2694410693.py:65: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(['No', 'Sí'])
# C:\Users\hugo_\AppData\Local\Temp\ipykernel_19952\2694410693.py:73: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['No', 'Sí'])
# C:\Users\hugo_\AppData\Local\Temp\ipykernel_19952\2694410693.py:65: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(['No', 'Sí'])
# C:\Users\hugo_\AppData\Local\Temp\ipykernel_19952\2694410693.py:73: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['No', 'Sí'])
# C:\Users\hugo_\AppData\Local\Temp\ipykernel_19952\2694410693.py:65: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(['No', 'Sí'])
# C:\Users\hugo_\AppData\Local\Temp\ipykernel_19952\2694410693.py:73: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['No', 'Sí'])
# C:\Users\hugo_\AppData\Local\Temp\ipykernel_19952\2694410693.py:65: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(['No', 'Sí'])
# C:\Users\hugo_\AppData\Local\Temp\ipykernel_19952\2694410693.py:73: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['No', 'Sí'])
# C:\Users\hugo_\AppData\Local\Temp\ipykernel_19952\2694410693.py:65: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(['No', 'Sí'])
# C:\Users\hugo_\AppData\Local\Temp\ipykernel_19952\2694410693.py:73: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['No', 'Sí'])
# C:\Users\hugo_\AppData\Local\Temp\ipykernel_19952\2694410693.py:65: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(['No', 'Sí'])
# C:\Users\hugo_\AppData\Local\Temp\ipykernel_19952\2694410693.py:73: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['No', 'Sí'])
# C:\Users\hugo_\AppData\Local\Temp\ipykernel_19952\2694410693.py:65: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(['No', 'Sí'])
# C:\Users\hugo_\AppData\Local\Temp\ipykernel_19952\2694410693.py:73: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['No', 'Sí'])
# C:\Users\hugo_\AppData\Local\Temp\ipykernel_19952\2694410693.py:65: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(['No', 'Sí'])
# C:\Users\hugo_\AppData\Local\Temp\ipykernel_19952\2694410693.py:73: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(['No', 'Sí'])
# Análisis bivariado completado. Se han generado:
# 1. Matrices de correlación/asociación:
#    - Correlación de Pearson para variables numéricas
#    - V de Cramer para variables categóricas
# 2. Visualizaciones:
#    - Violin plots y Box plots para variables numéricas vs SVI
#    - Gráficos de barras apiladas para variables categóricas vs SVI
# Todos los gráficos han sido guardados en los directorios correspondientes.
